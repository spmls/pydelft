# %%
from pydelft.read_griddep import grd, dep
import matplotlib.pyplot as plt
import numpy as np
import sys 
import os
# %matplotlib inline

# %%
gfname = r'i:\Aleutians\data\gridsanddepths\dutch_harbor_1sec\Sedanka_1sec_WGS84.grd'
dfname = r'i:\Aleutians\data\gridsanddepths\dutch_harbor_1sec\sedanka_1sec.dep'

# %%
sedanka_grid = grd(gfname)
sedanka_grid.plot_grd()

# %%
sedanka_depth = dep(dfname, gfname)
sedanka_depth.plot_dep()
